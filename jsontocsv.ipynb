# %%
import pandas as pd
from pandas import json_normalize
import json
f = open('25052003382.json', 'r') 
data = json.load(f)

# %%
#read JSON Data from file
print(data)
# Out:
# {'accountNumberInfo': [{'institutionId': '4019', 'refID': '25052003382', 'attemptID': '1A25052003382', 'product': 'CDL', 'dateTime': '2022-06-28T15:32:32.718+0530', 'responseDateTime': '2022-06-28T15:32:34.517+0530', 'bankName': 'HDFC BANK', 'bankBranch': 'AKOLA', 'accountNumber': '659462596546', 'accountType': 'SAVINGS', 'accountHolderFname': 'DSFHSDJHFGJ', 'accountHolderMname': '', 'accountHolderLname': '', 'ifscCode': 'HDFC0000221', 'yearsHeld': 2, 'bankingType': 'Primary', 'status': 'INVALID', 'validFlag': False, 'originalResponseCode': 'PNYERR1', 'originalResponseMsg': 'Invalid Beneficiary Mobile No / MAS', 'customMsg': 'Invalid Beneficiary Mobile No / MAS', 'currentBankingDecision': 'Approved', 'apiName': 'PAYNIMO'}], 'cpvData': 'NO_CONTENT', 'crossSellAddOnDetails': 'NO_CONTENT', 'extendedWarrantyDetails': 'NO_CONTENT', 'gngRefId': '25052003382', 'goNoGoCustomerApplication': {'actionList': [], 'intrimStatus': {'startTime': '2022-06-28T14:58:30.855+0530', 'appStart': 'DEFAULT',
# ...

# %%
print(type(data))
# Out:
# <class 'dict'>

# %%
print(data.keys())
# Out:
# dict_keys(['accountNumberInfo', 'cpvData', 'crossSellAddOnDetails', 'extendedWarrantyDetails', 'gngRefId', 'goNoGoCustomerApplication', 'institutionId', 'insurancePremiumDetails', 'losPushDate', 'loyaltyCardDetails', 'postIpaDoc', 'ricResponseData'])

# %%
for datatype in data.keys():
    print(datatype + "-")
    print(type(data[datatype]))
# Out:
# accountNumberInfo-
# <class 'list'>
# cpvData-
# <class 'str'>
# crossSellAddOnDetails-
# <class 'str'>
# extendedWarrantyDetails-
# <class 'str'>
# gngRefId-
# <class 'str'>
# goNoGoCustomerApplication-
# <class 'dict'>
# institutionId-
# <class 'str'>
# insurancePremiumDetails-
# <class 'str'>
# losPushDate-
# <class 'str'>
# loyaltyCardDetails-
# <class 'str'>
# postIpaDoc-
# <class 'dict'>
# ricResponseData-
# <class 'str'>

# %%
print(data['accountNumberInfo'][0])
# Out:
# {'institutionId': '4019', 'refID': '25052003382', 'attemptID': '1A25052003382', 'product': 'CDL', 'dateTime': '2022-06-28T15:32:32.718+0530', 'responseDateTime': '2022-06-28T15:32:34.517+0530', 'bankName': 'HDFC BANK', 'bankBranch': 'AKOLA', 'accountNumber': '659462596546', 'accountType': 'SAVINGS', 'accountHolderFname': 'DSFHSDJHFGJ', 'accountHolderMname': '', 'accountHolderLname': '', 'ifscCode': 'HDFC0000221', 'yearsHeld': 2, 'bankingType': 'Primary', 'status': 'INVALID', 'validFlag': False, 'originalResponseCode': 'PNYERR1', 'originalResponseMsg': 'Invalid Beneficiary Mobile No / MAS', 'customMsg': 'Invalid Beneficiary Mobile No / MAS', 'currentBankingDecision': 'Approved', 'apiName': 'PAYNIMO'}

# %%
for datatype in data['goNoGoCustomerApplication'].keys():
    print(datatype + "-")
    print(type(data['goNoGoCustomerApplication'][datatype]))
# Out:
# actionList-
# <class 'list'>
# intrimStatus-
# <class 'dict'>
# gngRefId-
# <class 'str'>
# parentID-
# <class 'str'>
# rootID-
# <class 'str'>
# productSequenceNumber-
# <class 'int'>
# dateTime-
# <class 'str'>
# applicationStatus-
# <class 'str'>
# statusFlag-
# <class 'bool'>
# reInitiateCount-
# <class 'int'>
# tvrCntLimit-
# <class 'int'>
# tvrNegCntLimit-
# <class 'int'>
# reLookCount-
# <class 'int'>
# losPushAttempts-
# <class 'int'>
# losPushInProgress-
# <class 'bool'>
# reAppraiseCount-
# <class 'int'>
# reappraiseReq-
# <class 'bool'>
# reProcessCount-
# <class 'int'>
# applicationRequest-
# <class 'dict'>
# applicantComponentResponse-
# <class 'dict'>
# applicantComponentResponseList-
# <class 'list'>
# croDecisions-
# <class 'list'>
# negativePincode-
# <class 'bool'>
# applScoreVector-
# <class 'list'>
# applicationLog-
# <class 'dict'>
# croJustification-
# <class 'list'>
# losDetails-
# <class 'dict'>
# invoiceDetails-
# <class 'dict'>
# subProcesses-
# ...

# %%
for datatype in data['goNoGoCustomerApplication']['intrimStatus'].keys():
    print(datatype + "-")
    print(type(data['goNoGoCustomerApplication']['intrimStatus'][datatype]))
# Out:
# startTime-
# <class 'str'>
# appStart-
# <class 'str'>
# dedupe-
# <class 'str'>
# posidexDedupeStatus-
# <class 'str'>
# p27BreStatus-
# <class 'str'>
# cdAppScoreStatus-
# <class 'str'>
# emailStatus-
# <class 'str'>
# otpStatus-
# <class 'str'>
# appsStatus-
# <class 'str'>
# panStatus-
# <class 'str'>
# aadharStatus-
# <class 'str'>
# mbStatus-
# <class 'str'>
# creditVidyaStatus-
# <class 'str'>
# saathiPullStatus-
# <class 'str'>
# varScoreStatus-
# <class 'str'>
# scoreStatus-
# <class 'str'>
# cibilScore-
# <class 'str'>
# equifaxScore-
# <class 'str'>
# experianStatus-
# <class 'str'>
# highmarkStatus-
# <class 'str'>
# equifaxStatus-
# <class 'str'>
# croStatus-
# <class 'str'>
# awsS3Status-
# <class 'str'>
# ntcStatus-
# <class 'str'>
# sherlockStatus-
# <class 'str'>
# ntcGngStatus-
# <class 'dict'>
# panModuleResult-
# <class 'dict'>
# cibilModuleResult-
# <class 'dict'>
# residenceAddressResult-
# <class 'dict'>
# officeModuleResult-
# <class 'dict'>
# ...

# %%
for datatype in data['goNoGoCustomerApplication']['intrimStatus']['ntcGngStatus'].keys():
    print(datatype + "-")
    print(type(data['goNoGoCustomerApplication']['intrimStatus']['ntcGngStatus'][datatype]))
# Out:
# message-
# <class 'str'>
# score-
# <class 'str'>
# band-
# <class 'str'>

# %%
#accountNumberInfo=data['accountNumberInfo'][0]
df =pd.json_normalize(data,
        record_path =['accountNumberInfo'],
        
    )

# %%
print(df)
# Out:
#   institutionId        refID      attemptID product  \
# 0          4019  25052003382  1A25052003382     CDL
#
#                        dateTime              responseDateTime   bankName  \
# 0  2022-06-28T15:32:32.718+0530  2022-06-28T15:32:34.517+0530  HDFC BANK
#
#   bankBranch accountNumber accountType  ...     ifscCode yearsHeld  \
# 0      AKOLA  659462596546     SAVINGS  ...  HDFC0000221         2
#
#   bankingType   status  validFlag originalResponseCode  \
# 0     Primary  INVALID      False              PNYERR1
#
#                    originalResponseMsg                            customMsg  \
# 0  Invalid Beneficiary Mobile No / MAS  Invalid Beneficiary Mobile No / MAS
#
#   currentBankingDecision  apiName
# 0               Approved  PAYNIMO
#
# [1 rows x 23 columns]

# %%
print(data['accountNumberInfo'][0].keys())
# Out:
# dict_keys(['institutionId', 'refID', 'attemptID', 'product', 'dateTime', 'responseDateTime', 'bankName', 'bankBranch', 'accountNumber', 'accountType', 'accountHolderFname', 'accountHolderMname', 'accountHolderLname', 'ifscCode', 'yearsHeld', 'bankingType', 'status', 'validFlag', 'originalResponseCode', 'originalResponseMsg', 'customMsg', 'currentBankingDecision', 'apiName'])
